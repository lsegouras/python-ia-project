# %% [markdown]
# # Projeto Python IA: Inteligência Artificial e Previsões
#
# ### Case: Score de Crédito dos Clientes
#
# Você foi contratado por um banco para conseguir definir o score de crédito dos clientes. Você precisa analisar todos os clientes do banco e, com base nessa análise, criar um modelo que consiga ler as informações do cliente e dizer automaticamente o score de crédito dele: Ruim, Ok, Bom
#
# Arquivos da aula: https://drive.google.com/drive/folders/1FbDqVq4XLvU85VBlVIMJ73p9oOu6u2-J?usp=drive_link

# %%
#Passo a Passo

#Passo 1 - importar base de dados e corrigir problemas dela
#Passo 2 - preparar dados para a inteligência artificial aprender
#Passo 3 - criar modelos de IA - modelo de score de crédito
#Passo 4 - comparar e escolher o melhor modelo
#Passo 5 - Usar IA para fazer novas previsões

#ferramentas:

#pandas, numpy
#scikit-learn

#Sugestão de site para pegar base de dados gratuitas - Kaggle

# %%
# !pip install pandas numpy scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.6 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.6 kB 330.3 kB/s eta 0:00:01
#      -------------------------------------- 60.6/60.6 kB 402.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#     --------------------------------------- 0.2/10.6 MB 6.3 MB/s eta 0:00:02
#    -- ------------------------------------- 0.6/10.6 MB 7.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.1/10.6 MB 7.6 MB/s eta 0:00:02
#    ------ --------------------------------- 1.6/10.6 MB 9.4 MB/s eta 0:00:01
#    -------- ------------------------------- 2.3/10.6 MB 9.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.9/10.6 MB 10.2 MB/s eta 0:00:01
#    ------------ --------------------------- 3.3/10.6 MB 10.0 MB/s eta 0:00:01
# ...
